# %%
def colour_vertices(graph):
    vertices = sorted(list(graph.keys()))
    colour_graph = {}
    
    # Dictionary to map colors to indices
    color_indices = {"Red": 0, "Green": 1, "Blue": 2}

    for vertex in vertices:
        unused_colours = len(vertices) * [True]

        for neighbor in graph[vertex]:
            if neighbor in colour_graph:
                colour = colour_graph[neighbor]
                unused_colours[color_indices[colour]] = False

        for colour, unused in enumerate(unused_colours):
            if unused:
                if colour == 0:
                    colour_graph[vertex] = "Red"
                elif colour == 1:
                    colour_graph[vertex] = "Green"
                elif colour == 2:
                    colour_graph[vertex] = "Blue"
                break

    return colour_graph

graph = {
    "Adair": ["Macon", "Schuyler", "Knox", "Linn", "Sullivan"],
    "Andrew": ["Holt", "Nodaway", "Gentry", "DeKalb", "Buchanan"],
    "Atchison": ["Holt", "Nodaway", "Brown", "Doniphan"],
    "Audrain": ["Monroe", "Ralls", "Pike", "Callaway", "Boone"],
    "Barry": ["Lawrence", "Stone", "Christian", "Greene"],
    "Barton": ["Vernon", "Cedar", "Dade", "Jasper", "St. Clair"],
    "Bates": ["Cass", "Henry", "Vernon", "St. Clair", "Cedar"],
    "Benton": ["St. Clair", "Hickory", "Polk", "Henry", "Pettis"],
    "Bollinger": ["Perry", "Cape Girardeau", "Madison", "Wayne", "Stoddard"],
    "Boone": ["Callaway", "Montgomery", "Cole", "Moniteau"],
    "Buchanan": ["Platte", "Clinton", "DeKalb", "Andrew"],
    "Butler": ["St. Clair", "Bates", "Cass", "Polk", "Dallas"],
    "Caldwell": ["Daviess", "Ray", "Clinton", "Carroll", "Livingston"],
    "Callaway": ["Montgomery", "Boone", "Audrain", "Osage", "Cole"],
    "Camden": ["Pulaski", "Miller", "Morgan", "Laclede"],
    "Cape Girardeau": ["Bollinger", "Perry", "Union", "Jackson"],
    "Carroll": ["Ray", "Chariton", "Livingston", "Caldwell"],
    "Carter": ["Reynolds", "Wayne", "Shannon", "Ripley"],
    "Cass": ["Johnson", "Jackson", "Bates", "Henry", "Johnson"],
    "Cedar": ["St. Clair", "Polk", "Dade", "Jasper", "Barton"],
    "Chariton": ["Linn", "Saline", "Carroll", "Howard"],
    "Christian": ["Greene", "Lawrence", "Stone", "Taney", "Douglas"],
    "Clark": ["Lewis", "Scotland", "Knox", "Scotland"],
    "Clay": ["Platte", "Ray", "Clinton", "Jackson"],
    "Clinton": ["Dekalb", "Buchanan", "Platte", "Clay", "Ray", "Caldwell"],
    "Cole": ["Moniteau", "Miller", "Osage", "Callaway", "Boone"],
    "Cooper": ["Howard", "Moniteau", "Morgan", "Pettis"],
    "Crawford": ["Washington", "Franklin", "Gasconade", "Phelps"],
    "Dade": ["Cedar", "Polk", "Greene", "Jasper", "Barton"],
    "Dallas": ["Polk", "Hickory", "Camden", "Laclede", "Webster"],
    "Daviess": ["Harrison", "Caldwell", "Grundy", "DeKalb", "Livingston"],
    "DeKalb": ["Clinton", "Buchanan", "Andrew", "Gentry", "Daviess"],
    "Dent": ["Reynolds", "Phelps", "Shannon", "Texas", "Crawford"],
    "Douglas": ["Howell", "Texas", "Wright", "Taney", "Christian"],
    "Dunklin": ["Stoddard", "New Madrid", "Pemiscot", "Butler"],
    "Franklin": ["Crawford", "Gasconade", "Warren", "St. Louis"],
    "Gasconade": ["Franklin", "Crawford", "Phelps", "Maries", "Osage"],
    "Gentry": ["Andrew", "Nodaway", "Worth", "DeKalb", "Harrison"],
    "Greene": ["Dade", "Christian", "Webster", "Lawrence"],
    "Grundy": ["Harrison", "Sullivan", "Mercer", "Linn", "Livingston"],
    "Harrison": ["Gentry", "Daviess", "Grundy", "Mercer"],
    "Henry": ["Cass", "Johnson", "Bates", "Benton", "St. Clair"],
    "Hickory": ["Polk", "Dallas", "Benton", "St. Clair", "Hickory"],
    "Holt": ["Atchison", "Nodaway", "Andrew"],
    "Howard": ["Chariton", "Cooper", "Boone", "Saline"],
    "Howell": ["Oregon", "Texas", "Douglas", "Texas"],
    "Iron": ["Madison", "St. Francois", "Washington", "Reynolds"],
    "Jackson": ["Lafayette", "Cass", "Johnson", "Clay", "Platte"],
    "Jasper": ["Newton", "Lawrence", "Dade", "Cedar", "Barton"],
    "Jefferson": ["Washington", "St. Francois", "St. Louis", "St. Louis City"],
    "Johnson": ["Lafayette", "Cass", "Henry", "Pettis", "Warren"],
    "Knox": ["Scotland", "Clark", "Lewis", "Adair"],
    "Laclede": ["Dallas", "Camden", "Pulaski", "Wright"],
    "Lafayette": ["Ray", "Jackson", "Johnson", "Pettis"],
    "Lawrence": ["Barry", "Greene", "Dade", "Newton"],
    "Lewis": ["Clark", "Knox", "Shelby", "Marion"],
    "Lincoln": ["Montgomery", "Warren", "St. Charles", "Pike"],
    "Linn": ["Livingston", "Sullivan", "Adair", "Chariton", "Macon"],
    "Livingston": ["Grundy", "Daviess", "Caldwell", "Carroll", "Linn"],
    "McDonald": ["Newton", "Barry", "Stone", "Newton"],
    "Macon": ["Adair", "Knox", "Shelby", "Linn", "Randolph"],
    "Madison": ["Iron", "Wayne", "St. Francois", "St. Francois"],
    "Maries": ["Phelps", "Gasconade", "Osage", "Miller"],
    "Marion": ["Shelby", "Lewis", "Ralls", "Monroe"],
    "Mercer": ["Harrison", "Grundy", "Sullivan", "Putnam"],
    "Miller": ["Maries", "Phelps", "Pulaski", "Camden", "Morgan"],
    "Mississippi": ["New Madrid", "Scott", "Cape Girardeau", "Butler"],
    "Moniteau": ["Cole", "Cooper", "Morgan", "Miller"],
    "Monroe": ["Shelby", "Ralls", "Pike", "Audrain"],
    "Montgomery": ["Lincoln", "Warren", "Gasconade", "Callaway", "Boone"],
    "Morgan": ["Miller", "Camden", "Pettis", "Cooper"],
    "New Madrid": ["Pemiscot", "Mississippi", "Stoddard", "Scott"],
    "Newton": ["Jasper", "McDonald", "Barry", "Lawrence"],
    "Nodaway": ["Worth", "Gentry", "Andrew", "Holt", "Atchison"],
    "Oregon": ["Shannon", "Howell", "Douglas", "Howell"],
    "Osage": ["Maries", "Gasconade", "Cole", "Miller"],
    "Ozark": ["Christian", "Taney", "Douglas", "Howell"],
    "Pemiscot": ["Dunklin", "New Madrid", "Mississippi", "Lake"],
    "Perry": ["Bollinger", "Cape Girardeau", "St. Francois", "Madison"],
    "Pettis": ["Benton", "Henry", "Johnson", "Lafayette", "Cooper"],
    "Phelps": ["Maries", "Texas", "Dent", "Crawford", "Gasconade"],
    "Pike": ["Audrain", "Montgomery", "Lincoln", "Ralls"],
    "Platte": ["Clay", "Clinton", "Buchanan", "Andrew", "Clinton"],
    "Polk": ["Dallas", "Cedar", "Dade", "Greene", "Hickory"],
    "Pulaski": ["Laclede", "Miller", "Phelps", "Texas"],
    "Putnam": ["Sullivan", "Mercer", "Schuyler", "Adair"],
    "Ralls": ["Marion", "Shelby", "Monroe", "Pike"],
    "Randolph": ["Shelby", "Macon", "Chariton", "Howard"],
    "Ray": ["Lafayette", "Clay", "Clinton", "Caldwell", "Carroll"],
    "Reynolds": ["Wayne", "Shannon", "Carter", "Dent", "Iron"],
    "Ripley": ["Butler", "Wayne", "Carter", "Oregon"],
    "St. Charles": ["Lincoln", "Warren", "St. Louis", "Franklin"],
    "St. Clair": ["Hickory", "Benton", "Henry", "Bates", "Cedar"],
    "Ste. Genevieve": ["Perry", "St. Francois", "Jefferson", "St. Francois"],
    "St. Francois": ["Madison", "Perry", "Ste. Genevieve", "Jefferson", "Iron"],
    "St. Louis": ["St. Charles", "Franklin", "Jefferson", "St. Louis City"],
    "St. Louis City": ["St. Louis", "Jefferson"],
    "Saline": ["Chariton", "Pettis", "Howard", "Cooper"],
    "Schuyler": ["Adair", "Putnam", "Scotland", "Linn"],
    "Scotland": ["Clark", "Knox", "Schuyler", "Clark"],
    "Scott": ["Mississippi", "New Madrid", "Cape Girardeau", "Stoddard"],
    "Shannon": ["Texas", "Reynolds", "Carter", "Oregon"],
    "Shelby": ["Monroe", "Marion", "Lewis", "Knox", "Randolph"],
    "Stoddard": ["Butler", "New Madrid", "Scott", "Bollinger"],
    "Stone": ["Christian", "Taney", "Douglas", "Howell"],
    "Sullivan": ["Adair", "Linn", "Grundy", "Putnam", "Mercer"],
    "Taney": ["Christian", "Douglas", "Ozark", "Stone"],
    "Texas": ["Wright", "Douglas", "Howell", "Phelps"],
    "Vernon": ["Barton", "Bates", "Cedar", "St. Clair", "Bates"],
    "Warren": ["Lincoln", "Montgomery", "St. Charles", "Franklin"],
    "Washington": ["St. Francois", "Jefferson", "Crawford", "Franklin"],
    "Wayne": ["Reynolds", "St. Francois", "Madison", "Carter", "Ripley"],
    "Webster": ["Greene", "Dallas", "Laclede", "Christian", "Douglas"],
    "Worth": ["Gentry", "Nodaway", "Harrison"],
    "Wright": ["Douglas", "Texas", "Laclede", "Webster"],
}

result = colour_vertices(graph)
print("********Final Mapping*******")
for i in result.items():
    print(i)
# Out:
# ********Final Mapping*******
# ('Adair', 'Red')
# ('Andrew', 'Red')
# ('Atchison', 'Red')
# ('Audrain', 'Red')
# ('Barry', 'Red')
# ('Barton', 'Red')
# ('Bates', 'Red')
# ('Benton', 'Red')
# ('Bollinger', 'Red')
# ('Boone', 'Red')
# ('Buchanan', 'Green')
# ('Butler', 'Green')
# ('Caldwell', 'Red')
# ('Callaway', 'Green')
# ('Camden', 'Red')
# ('Cape Girardeau', 'Green')
# ('Carroll', 'Green')
# ('Carter', 'Red')
# ('Cass', 'Green')
# ('Cedar', 'Green')
# ('Chariton', 'Red')
# ('Christian', 'Red')
# ('Clark', 'Red')
# ('Clay', 'Red')
# ('Clinton', 'Blue')
# ('Cole', 'Blue')
# ('Cooper', 'Red')
# ('Crawford', 'Red')
# ('Dade', 'Blue')
# ('Dallas', 'Green')
# ('Daviess', 'Green')
# ('Dent', 'Green')
# ('Douglas', 'Green')
# ('Dunklin', 'Red')
# ('Franklin', 'Green')
# ('Gasconade', 'Blue')
# ('Gentry', 'Green')
# ('Greene', 'Green')
# ('Grundy', 'Red')
# ('Harrison', 'Blue')
# ('Henry', 'Blue')
# ('Hickory', 'Blue')
# ('Holt', 'Green')
# ('Howard', 'Green')
# ('Howell', 'Red')
# ...
